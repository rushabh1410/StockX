# %%
import requests 
from bs4 import BeautifulSoup
import csv 
import pandas as pd
import smtplib

s = smtplib.SMTP('smtp.gmail.com',587)
s.ehlo()
s.starttls()
s.login('yasbhow@gmail.com','########')

names=[]
prices=[]
changes=[]
percentChanges=[]
marketCaps=[]
totalVolumes=[]
circulatingSupplys=[]
 
CryptoCurrenciesUrl = "https://in.finance.yahoo.com/gainers"
r= requests.get(CryptoCurrenciesUrl)
data=r.text
soup=BeautifulSoup(data)

for names1 in soup.find_all('td', attrs={'class':'Va(m) Ta(start) Px(10px) Fz(s)'}):
    names.append(names1.text)

    
for l1 in soup.find_all('td', attrs={'class':'Va(m) Ta(end) Pstart(20px) Fw(600) Fz(s)'}):
    for l2 in l1.find_all('span',attrs={'class':'Trsdu(0.3s)'}):
         prices.append(l2.text)    
prices1=prices[::3]
changes=prices[1::3]
percentChanges=prices[2::3]
x=pd.DataFrame({"Names": names, "Prices": prices1, "Change": changes, "% Change": percentChanges})

# %%
x
# Out:
#                                             Names  Prices   Change  % Change
# 0                   DATASOFT APPLICATION SOFTWARE  2.6400  +1.6900  +177.89%
# 1   Datasoft Application Software (India) Limited  2.6400  +1.6900  +177.89%
# 2                    Shekhawati Poly-Yarn Limited  0.2000  +0.0500   +33.33%
# 3                         Karuturi Global Limited  0.2000  +0.0500   +33.33%
# 4                                 IDFC Sensex ETF  325.00   +76.08   +30.56%
# ..                                            ...     ...      ...       ...
# 95                           SNL Bearings Limited  104.00   +12.70   +13.91%
# 96                           SNL Bearings Limited  104.00   +12.70   +13.91%
# 97                          Castrol India Limited  102.65   +12.50   +13.87%
# 98             Confidence Petroleum India Limited   16.05    +1.95   +13.83%
# 99             Confidence Petroleum India Limited   16.05    +1.95   +13.83%
#
# [100 rows x 4 columns]

# %%
def parsePrice():
    url = 'https://finance.yahoo.com/quote/AAPL?p=AAPL&.tsrc=fin-srch'
    r= requests.get(url)
    data=r.text
    soup=BeautifulSoup(data) 
    price = soup.find('div',{'class': 'My(6px) Pos(r) smartphone_Mt(6px)'}).find('span').text
    return price

while True:
    current_price=float(parsePrice())
    set_price = 250
    print("The current price is: ",current_price)
    if(current_price < set_price):
        s.sendmail('yasbhow@gmail.com','rshah093@uottawa.ca',"The current price of the share is less than set price,Good time to buy")
        break
# Out:
# The current price is:  245.52
